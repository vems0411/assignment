# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("olmp.csv")

# %% [markdown]
# **1. In how many cities Summer Olympics is held so far?**

# %%
data = []
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# **2.Which sport is having most number of Gold Medals so far? (Top 5)**

# %%
#df[df['Medal']=='Gold']
#df.groupby('Sport').mean()[''].sort_values(ascending = False).plot.bar()

# %% [markdown]
# **3. Which sport is having most number of medals so far? (Top 5)**

# %%
data = []

for Medal in df['Sport'].unique():
   # data.append([Sport , len(df[df['Sport']  == Sport])])
#data = pd.DataFrame(data,columns = ['Sport','Medal'])
#data=data.sort_values(by='Medal', ascending=False)#.plot(x = 'Sport', y = 'Medal')
# Out:
#   File "<ipython-input-93-8ba50989864f>", line 3
#     Medal in df['Sport'].unique():
#     ^
# IndentationError: unexpected indent

# %%
data
# Out:
#     Sport  Medal
# 0   Sport      0
# 32  Sport      0
# 24  Sport      0
# 25  Sport      0
# 26  Sport      0
# 27  Sport      0
# 28  Sport      0
# 29  Sport      0
# 30  Sport      0
# 31  Sport      0
# 33  Sport      0
# 22  Sport      0
# 34  Sport      0
# 35  Sport      0
# 36  Sport      0
# 37  Sport      0
# 38  Sport      0
# 39  Sport      0
# 40  Sport      0
# 41  Sport      0
# 23  Sport      0
# 21  Sport      0
# 1   Sport      0
# 10  Sport      0
# 2   Sport      0
# 3   Sport      0
# 4   Sport      0
# 5   Sport      0
# 6   Sport      0
# 7   Sport      0
# 8   Sport      0
# 9   Sport      0
# 11  Sport      0
# 20  Sport      0
# 12  Sport      0
# 13  Sport      0
# 14  Sport      0
# 15  Sport      0
# 16  Sport      0
# 17  Sport      0
# 18  Sport      0
# 19  Sport      0
# 42  Sport      0

# %% [markdown]
# **4. Which player has won most number of medals? (Top 5)**

# %%
data = []

for Athlete in df['Athlete'].unique():
    data.append([Athlete , len(df[df['Medal']  == Medal])])

# %%
data
# Out:
# [['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
#  ['Athlete', 0],
# ...

# %% [markdown]
# **5 Which player has won most number Gold Medals of medals? (Top5)**

# %% [markdown]
# **6. In which year India won first Gold Medal in Summer Olympics?**

# %%
data = []

for Country in df['Country'].unique():
    data.append([len(df[df['Country']  == 'IND'])])

# %%
data
# Out:
# [[184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
#  [184],
# ...

# %% [markdown]
# **7. Which event is most popular in terms on number of players? (Top 5)**

# %%
data = []

for Sport in df['Athlete'].unique ():
 data.append([Sport,len(df[df['Athlete'] == 'Athlete'])])

data = pd.DataFrame(data, columns= ['event','Athlete'])

# %%
data
# Out:
#        event  Athlete
# 0      Sport        0
# 1      Sport        0
# 2      Sport        0
# 3      Sport        0
# 4      Sport        0
# ...      ...      ...
# 22757  Sport        0
# 22758  Sport        0
# 22759  Sport        0
# 22760  Sport        0
# 22761  Sport        0
#
# [22762 rows x 2 columns]

# %% [markdown]
# **8. Which sport is having most female Gold Medalists? (Top 5)**

# %%
# no idea
